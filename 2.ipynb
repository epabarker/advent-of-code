# %% [markdown]
# - Find all repeating digits in range
# - Valid repetition length must be half of length of min or max
# - Get length of min, length of max.
# - Get all factors of either length of min or length of max, with limit of max length / 2 (need to fit two in)
# - Now we can only consider repeating patterns of length

# %% [markdown]
# Now we have valid sequence lengths for each pattern.
# * If empty set, we know no valid repetitions.
# * Consider all numbers from min(lower range, smallest n digit number), where n is valid_seq_len

# %% [markdown]
# ## Part 1

# %%
with open('2-input.txt', 'r') as f: ranges = f.read().strip().split(',')
total = 0
for r in ranges:
    seq_len = 0
    lower, upper = r.split('-') # Get lower and upper range 
    if len(lower) % 2 == 0: seq_len = (len(lower) // 2) # Check even length
    elif len(upper) % 2 == 0: seq_len = (len(upper) // 2) # Check even length
    print(f"Range: {r}, Sequence Length: {seq_len}")
    if seq_len == 0: continue # Skip if no valid sequence length
    
    min_n_digit = 10**(2*seq_len - 1)
    max_n_digit = (10**(2*seq_len)) - 1
    
    start = max(int(lower), min_n_digit)
    end = min(int(upper), max_n_digit)
    
    first_seq = str(start)[0:seq_len] # Get first sequence
    last_seq = str(end)[0:seq_len] # Get last sequence
    print(f"Valid Range: {start}-{end}, First Sequence: {first_seq}, Last Sequence: {last_seq}")
    for seq in range(int(first_seq), int(last_seq) + 1): # Iterate sequences
        id = int(str(seq)*2)
        if id in range(start, end + 1): # Check full number in range
            print(f"Found sequence: {str(seq)*2}") 
            total += id
        
print(f"Total Sum: {total}")
# Out:
# Range: 10327-17387, Sequence Length: 0
# Range: 74025-113072, Sequence Length: 3
# Valid Range: 100000-113072, First Sequence: 100, Last Sequence: 113
# Found sequence: 100100
# Found sequence: 101101
# Found sequence: 102102
# Found sequence: 103103
# Found sequence: 104104
# Found sequence: 105105
# Found sequence: 106106
# Found sequence: 107107
# Found sequence: 108108
# Found sequence: 109109
# Found sequence: 110110
# Found sequence: 111111
# Found sequence: 112112
# Range: 79725385-79874177, Sequence Length: 4
# Valid Range: 79725385-79874177, First Sequence: 7972, Last Sequence: 7987
# Found sequence: 79727972
# Found sequence: 79737973
# Found sequence: 79747974
# Found sequence: 79757975
# Found sequence: 79767976
# Found sequence: 79777977
# Found sequence: 79787978
# Found sequence: 79797979
# Found sequence: 79807980
# Found sequence: 79817981
# Found sequence: 79827982
# Found sequence: 79837983
# Found sequence: 79847984
# Found sequence: 79857985
# Found sequence: 79867986
# Range: 964628-1052240, Sequence Length: 3
# Valid Range: 964628-999999, First Sequence: 964, Last Sequence: 999
# Found sequence: 964964
# Found sequence: 965965
# Found sequence: 966966
# Found sequence: 967967
# Found sequence: 968968
# Found sequence: 969969
# Found sequence: 970970
# Found sequence: 971971
# Found sequence: 972972
# Found sequence: 973973
# Found sequence: 974974
# Found sequence: 975975
# Found sequence: 976976
# Found sequence: 977977
# Found sequence: 978978
# Found sequence: 979979
# Found sequence: 980980
# Found sequence: 981981
# Found sequence: 982982
# Found sequence: 983983
# Found sequence: 984984
# Found sequence: 985985
# Found sequence: 986986
# Found sequence: 987987
# Found sequence: 988988
# Found sequence: 989989
# Found sequence: 990990
# Found sequence: 991991
# Found sequence: 992992
# Found sequence: 993993
# Found sequence: 994994
# Found sequence: 995995
# Found sequence: 996996
# Found sequence: 997997
# Found sequence: 998998
# Found sequence: 999999
# Range: 148-297, Sequence Length: 0
# Range: 3-16, Sequence Length: 1
# Valid Range: 10-16, First Sequence: 1, Last Sequence: 1
# Found sequence: 11
# Range: 126979-227778, Sequence Length: 3
# Valid Range: 126979-227778, First Sequence: 126, Last Sequence: 227
# Found sequence: 127127
# Found sequence: 128128
# Found sequence: 129129
# Found sequence: 130130
# Found sequence: 131131
# Found sequence: 132132
# Found sequence: 133133
# Found sequence: 134134
# Found sequence: 135135
# Found sequence: 136136
# Found sequence: 137137
# Found sequence: 138138
# Found sequence: 139139
# Found sequence: 140140
# Found sequence: 141141
# Found sequence: 142142
# Found sequence: 143143
# Found sequence: 144144
# Found sequence: 145145
# Found sequence: 146146
# Found sequence: 147147
# Found sequence: 148148
# Found sequence: 149149
# Found sequence: 150150
# Found sequence: 151151
# Found sequence: 152152
# Found sequence: 153153
# Found sequence: 154154
# Found sequence: 155155
# Found sequence: 156156
# Found sequence: 157157
# Found sequence: 158158
# Found sequence: 159159
# Found sequence: 160160
# Found sequence: 161161
# Found sequence: 162162
# Found sequence: 163163
# Found sequence: 164164
# Found sequence: 165165
# Found sequence: 166166
# Found sequence: 167167
# Found sequence: 168168
# Found sequence: 169169
# Found sequence: 170170
# Found sequence: 171171
# Found sequence: 172172
# Found sequence: 173173
# Found sequence: 174174
# Found sequence: 175175
# Found sequence: 176176
# Found sequence: 177177
# Found sequence: 178178
# Found sequence: 179179
# Found sequence: 180180
# Found sequence: 181181
# Found sequence: 182182
# Found sequence: 183183
# Found sequence: 184184
# Found sequence: 185185
# Found sequence: 186186
# Found sequence: 187187
# Found sequence: 188188
# Found sequence: 189189
# Found sequence: 190190
# Found sequence: 191191
# Found sequence: 192192
# Found sequence: 193193
# Found sequence: 194194
# Found sequence: 195195
# Found sequence: 196196
# Found sequence: 197197
# Found sequence: 198198
# Found sequence: 199199
# Found sequence: 200200
# Found sequence: 201201
# Found sequence: 202202
# Found sequence: 203203
# Found sequence: 204204
# Found sequence: 205205
# Found sequence: 206206
# Found sequence: 207207
# Found sequence: 208208
# Found sequence: 209209
# Found sequence: 210210
# Found sequence: 211211
# Found sequence: 212212
# Found sequence: 213213
# Found sequence: 214214
# Found sequence: 215215
# Found sequence: 216216
# Found sequence: 217217
# Found sequence: 218218
# Found sequence: 219219
# Found sequence: 220220
# Found sequence: 221221
# Found sequence: 222222
# Found sequence: 223223
# Found sequence: 224224
# Found sequence: 225225
# Found sequence: 226226
# Found sequence: 227227
# Range: 1601-2998, Sequence Length: 2
# Valid Range: 1601-2998, First Sequence: 16, Last Sequence: 29
# Found sequence: 1616
# Found sequence: 1717
# Found sequence: 1818
# Found sequence: 1919
# Found sequence: 2020
# Found sequence: 2121
# Found sequence: 2222
# Found sequence: 2323
# Found sequence: 2424
# Found sequence: 2525
# Found sequence: 2626
# Found sequence: 2727
# Found sequence: 2828
# Found sequence: 2929
# Range: 784-1207, Sequence Length: 2
# Valid Range: 1000-1207, First Sequence: 10, Last Sequence: 12
# Found sequence: 1010
# Found sequence: 1111
# Range: 831289-917268, Sequence Length: 3
# Valid Range: 831289-917268, First Sequence: 831, Last Sequence: 917
# Found sequence: 831831
# Found sequence: 832832
# Found sequence: 833833
# Found sequence: 834834
# Found sequence: 835835
# Found sequence: 836836
# Found sequence: 837837
# Found sequence: 838838
# Found sequence: 839839
# Found sequence: 840840
# Found sequence: 841841
# Found sequence: 842842
# Found sequence: 843843
# Found sequence: 844844
# Found sequence: 845845
# Found sequence: 846846
# Found sequence: 847847
# Found sequence: 848848
# Found sequence: 849849
# Found sequence: 850850
# Found sequence: 851851
# Found sequence: 852852
# Found sequence: 853853
# Found sequence: 854854
# Found sequence: 855855
# Found sequence: 856856
# Found sequence: 857857
# Found sequence: 858858
# Found sequence: 859859
# Found sequence: 860860
# Found sequence: 861861
# Found sequence: 862862
# Found sequence: 863863
# Found sequence: 864864
# Found sequence: 865865
# Found sequence: 866866
# Found sequence: 867867
# Found sequence: 868868
# Found sequence: 869869
# Found sequence: 870870
# Found sequence: 871871
# Found sequence: 872872
# Found sequence: 873873
# Found sequence: 874874
# Found sequence: 875875
# Found sequence: 876876
# Found sequence: 877877
# Found sequence: 878878
# Found sequence: 879879
# Found sequence: 880880
# Found sequence: 881881
# Found sequence: 882882
# Found sequence: 883883
# Found sequence: 884884
# Found sequence: 885885
# Found sequence: 886886
# Found sequence: 887887
# Found sequence: 888888
# Found sequence: 889889
# Found sequence: 890890
# Found sequence: 891891
# Found sequence: 892892
# Found sequence: 893893
# Found sequence: 894894
# Found sequence: 895895
# Found sequence: 896896
# Found sequence: 897897
# Found sequence: 898898
# Found sequence: 899899
# Found sequence: 900900
# Found sequence: 901901
# Found sequence: 902902
# Found sequence: 903903
# Found sequence: 904904
# Found sequence: 905905
# Found sequence: 906906
# Found sequence: 907907
# Found sequence: 908908
# Found sequence: 909909
# Found sequence: 910910
# Found sequence: 911911
# Found sequence: 912912
# Found sequence: 913913
# Found sequence: 914914
# Found sequence: 915915
# Found sequence: 916916
# Range: 55603410-55624466, Sequence Length: 4
# Valid Range: 55603410-55624466, First Sequence: 5560, Last Sequence: 5562
# Found sequence: 55605560
# Found sequence: 55615561
# Range: 317-692, Sequence Length: 0
# Range: 602197-750430, Sequence Length: 3
# Valid Range: 602197-750430, First Sequence: 602, Last Sequence: 750
# Found sequence: 602602
# Found sequence: 603603
# Found sequence: 604604
# Found sequence: 605605
# Found sequence: 606606
# Found sequence: 607607
# Found sequence: 608608
# Found sequence: 609609
# Found sequence: 610610
# Found sequence: 611611
# Found sequence: 612612
# Found sequence: 613613
# Found sequence: 614614
# Found sequence: 615615
# Found sequence: 616616
# Found sequence: 617617
# Found sequence: 618618
# Found sequence: 619619
# Found sequence: 620620
# Found sequence: 621621
# Found sequence: 622622
# Found sequence: 623623
# Found sequence: 624624
# Found sequence: 625625
# Found sequence: 626626
# Found sequence: 627627
# Found sequence: 628628
# Found sequence: 629629
# Found sequence: 630630
# Found sequence: 631631
# Found sequence: 632632
# Found sequence: 633633
# Found sequence: 634634
# Found sequence: 635635
# Found sequence: 636636
# Found sequence: 637637
# Found sequence: 638638
# Found sequence: 639639
# Found sequence: 640640
# Found sequence: 641641
# Found sequence: 642642
# Found sequence: 643643
# Found sequence: 644644
# Found sequence: 645645
# Found sequence: 646646
# Found sequence: 647647
# Found sequence: 648648
# Found sequence: 649649
# Found sequence: 650650
# Found sequence: 651651
# Found sequence: 652652
# Found sequence: 653653
# Found sequence: 654654
# Found sequence: 655655
# Found sequence: 656656
# Found sequence: 657657
# Found sequence: 658658
# Found sequence: 659659
# Found sequence: 660660
# Found sequence: 661661
# Found sequence: 662662
# Found sequence: 663663
# Found sequence: 664664
# Found sequence: 665665
# Found sequence: 666666
# Found sequence: 667667
# Found sequence: 668668
# Found sequence: 669669
# Found sequence: 670670
# Found sequence: 671671
# Found sequence: 672672
# Found sequence: 673673
# Found sequence: 674674
# Found sequence: 675675
# Found sequence: 676676
# Found sequence: 677677
# Found sequence: 678678
# Found sequence: 679679
# Found sequence: 680680
# Found sequence: 681681
# Found sequence: 682682
# Found sequence: 683683
# Found sequence: 684684
# Found sequence: 685685
# Found sequence: 686686
# Found sequence: 687687
# Found sequence: 688688
# Found sequence: 689689
# Found sequence: 690690
# Found sequence: 691691
# Found sequence: 692692
# Found sequence: 693693
# Found sequence: 694694
# Found sequence: 695695
# Found sequence: 696696
# Found sequence: 697697
# Found sequence: 698698
# Found sequence: 699699
# Found sequence: 700700
# Found sequence: 701701
# Found sequence: 702702
# Found sequence: 703703
# Found sequence: 704704
# Found sequence: 705705
# Found sequence: 706706
# Found sequence: 707707
# Found sequence: 708708
# Found sequence: 709709
# Found sequence: 710710
# Found sequence: 711711
# Found sequence: 712712
# Found sequence: 713713
# Found sequence: 714714
# Found sequence: 715715
# Found sequence: 716716
# Found sequence: 717717
# Found sequence: 718718
# Found sequence: 719719
# Found sequence: 720720
# Found sequence: 721721
# Found sequence: 722722
# Found sequence: 723723
# Found sequence: 724724
# Found sequence: 725725
# Found sequence: 726726
# Found sequence: 727727
# Found sequence: 728728
# Found sequence: 729729
# Found sequence: 730730
# Found sequence: 731731
# Found sequence: 732732
# Found sequence: 733733
# Found sequence: 734734
# Found sequence: 735735
# Found sequence: 736736
# Found sequence: 737737
# Found sequence: 738738
# Found sequence: 739739
# Found sequence: 740740
# Found sequence: 741741
# Found sequence: 742742
# Found sequence: 743743
# Found sequence: 744744
# Found sequence: 745745
# Found sequence: 746746
# Found sequence: 747747
# Found sequence: 748748
# Found sequence: 749749
# Range: 17-32, Sequence Length: 1
# Valid Range: 17-32, First Sequence: 1, Last Sequence: 3
# Found sequence: 22
# Range: 38-58, Sequence Length: 1
# Valid Range: 38-58, First Sequence: 3, Last Sequence: 5
# Found sequence: 44
# Found sequence: 55
# Range: 362012-455626, Sequence Length: 3
# Valid Range: 362012-455626, First Sequence: 362, Last Sequence: 455
# Found sequence: 362362
# Found sequence: 363363
# Found sequence: 364364
# Found sequence: 365365
# Found sequence: 366366
# Found sequence: 367367
# Found sequence: 368368
# Found sequence: 369369
# Found sequence: 370370
# Found sequence: 371371
# Found sequence: 372372
# Found sequence: 373373
# Found sequence: 374374
# Found sequence: 375375
# Found sequence: 376376
# Found sequence: 377377
# Found sequence: 378378
# Found sequence: 379379
# Found sequence: 380380
# Found sequence: 381381
# Found sequence: 382382
# Found sequence: 383383
# Found sequence: 384384
# Found sequence: 385385
# Found sequence: 386386
# Found sequence: 387387
# Found sequence: 388388
# Found sequence: 389389
# Found sequence: 390390
# Found sequence: 391391
# Found sequence: 392392
# Found sequence: 393393
# Found sequence: 394394
# Found sequence: 395395
# Found sequence: 396396
# Found sequence: 397397
# Found sequence: 398398
# Found sequence: 399399
# Found sequence: 400400
# Found sequence: 401401
# Found sequence: 402402
# Found sequence: 403403
# Found sequence: 404404
# Found sequence: 405405
# Found sequence: 406406
# Found sequence: 407407
# Found sequence: 408408
# Found sequence: 409409
# Found sequence: 410410
# Found sequence: 411411
# Found sequence: 412412
# Found sequence: 413413
# Found sequence: 414414
# Found sequence: 415415
# Found sequence: 416416
# Found sequence: 417417
# Found sequence: 418418
# Found sequence: 419419
# Found sequence: 420420
# Found sequence: 421421
# Found sequence: 422422
# Found sequence: 423423
# Found sequence: 424424
# Found sequence: 425425
# Found sequence: 426426
# Found sequence: 427427
# Found sequence: 428428
# Found sequence: 429429
# Found sequence: 430430
# Found sequence: 431431
# Found sequence: 432432
# Found sequence: 433433
# Found sequence: 434434
# Found sequence: 435435
# Found sequence: 436436
# Found sequence: 437437
# Found sequence: 438438
# Found sequence: 439439
# Found sequence: 440440
# Found sequence: 441441
# Found sequence: 442442
# Found sequence: 443443
# Found sequence: 444444
# Found sequence: 445445
# Found sequence: 446446
# Found sequence: 447447
# Found sequence: 448448
# Found sequence: 449449
# Found sequence: 450450
# Found sequence: 451451
# Found sequence: 452452
# Found sequence: 453453
# Found sequence: 454454
# Found sequence: 455455
# Range: 3622441-3647505, Sequence Length: 0
# Range: 883848601-883920224, Sequence Length: 0
# Range: 62-105, Sequence Length: 1
# Valid Range: 62-99, First Sequence: 6, Last Sequence: 9
# Found sequence: 66
# Found sequence: 77
# Found sequence: 88
# Found sequence: 99
# Range: 766880-804855, Sequence Length: 3
# Valid Range: 766880-804855, First Sequence: 766, Last Sequence: 804
# Found sequence: 767767
# Found sequence: 768768
# Found sequence: 769769
# Found sequence: 770770
# Found sequence: 771771
# Found sequence: 772772
# Found sequence: 773773
# Found sequence: 774774
# Found sequence: 775775
# Found sequence: 776776
# Found sequence: 777777
# Found sequence: 778778
# Found sequence: 779779
# Found sequence: 780780
# Found sequence: 781781
# Found sequence: 782782
# Found sequence: 783783
# Found sequence: 784784
# Found sequence: 785785
# Found sequence: 786786
# Found sequence: 787787
# Found sequence: 788788
# Found sequence: 789789
# Found sequence: 790790
# Found sequence: 791791
# Found sequence: 792792
# Found sequence: 793793
# Found sequence: 794794
# Found sequence: 795795
# Found sequence: 796796
# Found sequence: 797797
# Found sequence: 798798
# Found sequence: 799799
# Found sequence: 800800
# Found sequence: 801801
# Found sequence: 802802
# Found sequence: 803803
# Found sequence: 804804
# Range: 9184965756-9185005415, Sequence Length: 5
# Valid Range: 9184965756-9185005415, First Sequence: 91849, Last Sequence: 91850
# Found sequence: 9184991849
# Range: 490073-570277, Sequence Length: 3
# Valid Range: 490073-570277, First Sequence: 490, Last Sequence: 570
# Found sequence: 490490
# Found sequence: 491491
# Found sequence: 492492
# Found sequence: 493493
# Found sequence: 494494
# Found sequence: 495495
# Found sequence: 496496
# Found sequence: 497497
# Found sequence: 498498
# Found sequence: 499499
# Found sequence: 500500
# Found sequence: 501501
# Found sequence: 502502
# Found sequence: 503503
# Found sequence: 504504
# Found sequence: 505505
# Found sequence: 506506
# Found sequence: 507507
# Found sequence: 508508
# Found sequence: 509509
# Found sequence: 510510
# Found sequence: 511511
# Found sequence: 512512
# Found sequence: 513513
# Found sequence: 514514
# Found sequence: 515515
# Found sequence: 516516
# Found sequence: 517517
# Found sequence: 518518
# Found sequence: 519519
# Found sequence: 520520
# Found sequence: 521521
# Found sequence: 522522
# Found sequence: 523523
# Found sequence: 524524
# Found sequence: 525525
# Found sequence: 526526
# Found sequence: 527527
# Found sequence: 528528
# Found sequence: 529529
# Found sequence: 530530
# Found sequence: 531531
# Found sequence: 532532
# Found sequence: 533533
# Found sequence: 534534
# Found sequence: 535535
# Found sequence: 536536
# Found sequence: 537537
# Found sequence: 538538
# Found sequence: 539539
# Found sequence: 540540
# Found sequence: 541541
# Found sequence: 542542
# Found sequence: 543543
# Found sequence: 544544
# Found sequence: 545545
# Found sequence: 546546
# Found sequence: 547547
# Found sequence: 548548
# Found sequence: 549549
# Found sequence: 550550
# Found sequence: 551551
# Found sequence: 552552
# Found sequence: 553553
# Found sequence: 554554
# Found sequence: 555555
# Found sequence: 556556
# Found sequence: 557557
# Found sequence: 558558
# Found sequence: 559559
# Found sequence: 560560
# Found sequence: 561561
# Found sequence: 562562
# Found sequence: 563563
# Found sequence: 564564
# Found sequence: 565565
# Found sequence: 566566
# Found sequence: 567567
# Found sequence: 568568
# Found sequence: 569569
# Range: 2929273115-2929318135, Sequence Length: 5
# Valid Range: 2929273115-2929318135, First Sequence: 29292, Last Sequence: 29293
# Range: 23251-48475, Sequence Length: 0
# Range: 9696863768-9697013088, Sequence Length: 5
# Valid Range: 9696863768-9697013088, First Sequence: 96968, Last Sequence: 96970
# Found sequence: 9696896968
# Found sequence: 9696996969
# Range: 229453-357173, Sequence Length: 3
# Valid Range: 229453-357173, First Sequence: 229, Last Sequence: 357
# Found sequence: 230230
# Found sequence: 231231
# Found sequence: 232232
# Found sequence: 233233
# Found sequence: 234234
# Found sequence: 235235
# Found sequence: 236236
# Found sequence: 237237
# Found sequence: 238238
# Found sequence: 239239
# Found sequence: 240240
# Found sequence: 241241
# Found sequence: 242242
# Found sequence: 243243
# Found sequence: 244244
# Found sequence: 245245
# Found sequence: 246246
# Found sequence: 247247
# Found sequence: 248248
# Found sequence: 249249
# Found sequence: 250250
# Found sequence: 251251
# Found sequence: 252252
# Found sequence: 253253
# Found sequence: 254254
# Found sequence: 255255
# Found sequence: 256256
# Found sequence: 257257
# Found sequence: 258258
# Found sequence: 259259
# Found sequence: 260260
# Found sequence: 261261
# Found sequence: 262262
# Found sequence: 263263
# Found sequence: 264264
# Found sequence: 265265
# Found sequence: 266266
# Found sequence: 267267
# Found sequence: 268268
# Found sequence: 269269
# Found sequence: 270270
# Found sequence: 271271
# Found sequence: 272272
# Found sequence: 273273
# Found sequence: 274274
# Found sequence: 275275
# Found sequence: 276276
# Found sequence: 277277
# Found sequence: 278278
# Found sequence: 279279
# Found sequence: 280280
# Found sequence: 281281
# Found sequence: 282282
# Found sequence: 283283
# Found sequence: 284284
# Found sequence: 285285
# Found sequence: 286286
# Found sequence: 287287
# Found sequence: 288288
# Found sequence: 289289
# Found sequence: 290290
# Found sequence: 291291
# Found sequence: 292292
# Found sequence: 293293
# Found sequence: 294294
# Found sequence: 295295
# Found sequence: 296296
# Found sequence: 297297
# Found sequence: 298298
# Found sequence: 299299
# Found sequence: 300300
# Found sequence: 301301
# Found sequence: 302302
# Found sequence: 303303
# Found sequence: 304304
# Found sequence: 305305
# Found sequence: 306306
# Found sequence: 307307
# Found sequence: 308308
# Found sequence: 309309
# Found sequence: 310310
# Found sequence: 311311
# Found sequence: 312312
# Found sequence: 313313
# Found sequence: 314314
# Found sequence: 315315
# Found sequence: 316316
# Found sequence: 317317
# Found sequence: 318318
# Found sequence: 319319
# Found sequence: 320320
# Found sequence: 321321
# Found sequence: 322322
# Found sequence: 323323
# Found sequence: 324324
# Found sequence: 325325
# Found sequence: 326326
# Found sequence: 327327
# Found sequence: 328328
# Found sequence: 329329
# Found sequence: 330330
# Found sequence: 331331
# Found sequence: 332332
# Found sequence: 333333
# Found sequence: 334334
# Found sequence: 335335
# Found sequence: 336336
# Found sequence: 337337
# Found sequence: 338338
# Found sequence: 339339
# Found sequence: 340340
# Found sequence: 341341
# Found sequence: 342342
# Found sequence: 343343
# Found sequence: 344344
# Found sequence: 345345
# Found sequence: 346346
# Found sequence: 347347
# Found sequence: 348348
# Found sequence: 349349
# Found sequence: 350350
# Found sequence: 351351
# Found sequence: 352352
# Found sequence: 353353
# Found sequence: 354354
# Found sequence: 355355
# Found sequence: 356356
# Range: 29283366-29304416, Sequence Length: 4
# Valid Range: 29283366-29304416, First Sequence: 2928, Last Sequence: 2930
# Found sequence: 29292929
# Found sequence: 29302930
# Range: 4526-8370, Sequence Length: 2
# Valid Range: 4526-8370, First Sequence: 45, Last Sequence: 83
# Found sequence: 4545
# Found sequence: 4646
# Found sequence: 4747
# Found sequence: 4848
# Found sequence: 4949
# Found sequence: 5050
# Found sequence: 5151
# Found sequence: 5252
# Found sequence: 5353
# Found sequence: 5454
# Found sequence: 5555
# Found sequence: 5656
# Found sequence: 5757
# Found sequence: 5858
# Found sequence: 5959
# Found sequence: 6060
# Found sequence: 6161
# Found sequence: 6262
# Found sequence: 6363
# Found sequence: 6464
# Found sequence: 6565
# Found sequence: 6666
# Found sequence: 6767
# Found sequence: 6868
# Found sequence: 6969
# Found sequence: 7070
# Found sequence: 7171
# Found sequence: 7272
# Found sequence: 7373
# Found sequence: 7474
# Found sequence: 7575
# Found sequence: 7676
# Found sequence: 7777
# Found sequence: 7878
# Found sequence: 7979
# Found sequence: 8080
# Found sequence: 8181
# Found sequence: 8282
# Range: 3095-4389, Sequence Length: 2
# Valid Range: 3095-4389, First Sequence: 30, Last Sequence: 43
# Found sequence: 3131
# Found sequence: 3232
# Found sequence: 3333
# Found sequence: 3434
# Found sequence: 3535
# Found sequence: 3636
# Found sequence: 3737
# Found sequence: 3838
# Found sequence: 3939
# Found sequence: 4040
# Found sequence: 4141
# Found sequence: 4242
# Found sequence: 4343
# Range: 4400617-4493438, Sequence Length: 0
# Total Sum: 30323879646

# %% [markdown]
# ## Part 2

# %%
range_tuples = [tuple(r.split('-')) for r in ranges]
standard_ranges = []
for lower,upper in range_tuples:
    if len(upper) != len(lower):
        mid = 10**(len(upper)-1)
        standard_ranges.append((lower,str(mid-1)))
        standard_ranges.append((str(mid),upper))
    else:
        standard_ranges.append((lower,upper))
        
invalid_ids = set()
for lower,upper in standard_ranges:
    # Anything that repeats must be a factor of the length of the id
    divisors = [i for i in range(1, (len(lower)//2 + 1)) if len(lower) % i == 0]
    # For each divisor of the length of the id
    for d in divisors:
        # Must start with repeat >= start of lower bound of same length
        start = lower[:d]
        repeat = int(start)
        print(f"Lower: {lower}, Upper: {upper}, Divisor: {d}, Start: {start}")
        # Generate id by doing string repetition
        id = str(repeat)*int(len(upper)/int(d))  # ← Changed here
        # Continue whilst the generated id is less than upper range
        while int(id) <= int(upper):
            if int(id) >= int(lower):  # ← Still need this!
                invalid_ids.add(id)
                print(id)
            repeat += 1
            id = str(repeat)*int(len(lower)/int(d))
            
            
invalid_ids_list = [int(id) for id in invalid_ids]
total = sum(invalid_ids_list)
print(f"Total: {total}")
# Out:
# Lower: 10327, Upper: 17387, Divisor: 1, Start: 1
# 11111
# Lower: 74025, Upper: 99999, Divisor: 1, Start: 7
# 77777
# 88888
# 99999
# Lower: 100000, Upper: 113072, Divisor: 1, Start: 1
# 111111
# Lower: 100000, Upper: 113072, Divisor: 2, Start: 10
# 101010
# 111111
# Lower: 100000, Upper: 113072, Divisor: 3, Start: 100
# 100100
# 101101
# 102102
# 103103
# 104104
# 105105
# 106106
# 107107
# 108108
# 109109
# 110110
# 111111
# 112112
# Lower: 79725385, Upper: 79874177, Divisor: 1, Start: 7
# Lower: 79725385, Upper: 79874177, Divisor: 2, Start: 79
# 79797979
# Lower: 79725385, Upper: 79874177, Divisor: 4, Start: 7972
# 79727972
# 79737973
# 79747974
# 79757975
# 79767976
# 79777977
# 79787978
# 79797979
# 79807980
# 79817981
# 79827982
# 79837983
# 79847984
# 79857985
# 79867986
# Lower: 964628, Upper: 999999, Divisor: 1, Start: 9
# 999999
# Lower: 964628, Upper: 999999, Divisor: 2, Start: 96
# 969696
# 979797
# 989898
# 999999
# Lower: 964628, Upper: 999999, Divisor: 3, Start: 964
# 964964
# 965965
# 966966
# 967967
# 968968
# 969969
# 970970
# 971971
# 972972
# 973973
# 974974
# 975975
# 976976
# 977977
# 978978
# 979979
# 980980
