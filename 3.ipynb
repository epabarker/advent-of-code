# %%
with open('3-input.txt', 'r') as f:
    banks = np.array([np.array([int(d) for d in line.strip()]) for line in f])

# %%
banks
# Out:
# array([[5, 3, 1, ..., 2, 5, 3],
#        [4, 6, 4, ..., 3, 9, 3],
#        [4, 3, 6, ..., 5, 5, 4],
#        ...,
#        [4, 4, 2, ..., 3, 4, 3],
#        [2, 2, 1, ..., 4, 3, 4],
#        [4, 5, 3, ..., 9, 4, 3]], shape=(200, 100))

# %%
eg = banks[0]

# %%
joltage = (0,1)

# %%
joltage[1]
# Out:
# 1

# %%
joltage[0]
# Out:
# np.int64(0)

# %%
joltages = []
for bank in banks:
    joltage = np.zeros(2,dtype=int)
    for battery in bank:
        if joltage[1] < battery: joltage[1] = battery 
        if joltage[1] > joltage[0]: joltage[0],joltage[1] = joltage[1],joltage[0] 
    joltages.append(joltage)

# %%
joltages[0][0]
# Out:
# np.int64(7)

# %%
joltages[0][1]
# Out:
# np.int64(5)

# %%
batteries[0]
# Out:
# array([5, 3, 1, 3, 3, 1, 3, 2, 2, 2, 1, 3, 3, 2, 2, 3, 2, 3, 2, 2, 2, 2,
#        1, 7, 3, 2, 2, 2, 2, 2, 1, 3, 2, 2, 2, 3, 2, 2, 4, 3, 5, 2, 2, 2,
#        2, 2, 4, 3, 2, 4, 2, 2, 2, 2, 3, 2, 2, 3, 2, 3, 2, 2, 2, 2, 3, 2,
#        2, 3, 2, 2, 3, 3, 2, 1, 2, 2, 5, 2, 5, 3, 2, 2, 1, 3, 2, 2, 3, 2,
#        3, 2, 5, 5, 2, 3, 2, 4, 3, 2, 5, 3])
