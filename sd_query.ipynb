# %%
import pandas as pd

pop_loc = pd.read_csv(r"C:\Users\EdwardBarker\Downloads\pop_location.csv")

# %%
pop_loc = pop_loc.drop(columns=["Participant ID"])

# %%
pop_loc
# Out:
#    population_area_size  Total number of patients with AD (any stage)  \
# 0                 Urban                                          2500
# 1                 Rural                                           700
# 2                 Urban                                          2773
# 3                 Urban                                           720
# 4              Suburban                                          1500
# 5                 Urban                                           750
# 6                 Urban                                           436
# 7                 Rural                                          2500
# 8                 Urban                                          2000
# 9                 Urban                                          1000
# 10                Urban                                          2416
# 11                Urban                                           130
#
#     Total number of patients with early AD  \
# ...

# %%
grouped = pop_loc.groupby('population_area_size')
result = grouped.mean().round(2).astype(str) + ' ± ' + grouped.std().round(2).astype(str)
result
# Out:
#                      Total number of patients with AD (any stage)  \
# population_area_size
# Rural                                            1600.0 ± 1272.79
# Suburban                                             1500.0 ± nan
# Urban                                           1413.89 ± 1004.54
#
#                      Total number of patients with early AD  \
# population_area_size
# Rural                                        875.0 ± 883.88
# Suburban                                        500.0 ± nan
# Urban                                       648.89 ± 491.83
#
#                      Total number of new patients with AD dementia (any stage)  \
# population_area_size
# Rural                                                       200.0 ± 0.0
# Suburban                                                    500.0 ± nan
# Urban                                                   317.78 ± 187.34
#
# ...
